# %% [markdown]
# ## This program is to train the model to recognise the data for face recognition program.

# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# <h3 style='color:purple'>(1) Preprocessing: Detect face and eyes</h3>

# %%
img = cv2.imread('./My Images/maria_sharapova/monochrome-maria-sharapova-face-wallpaper-65016-67225-hd-wallpapers.jpg')
img.shape
# Out:
# (1080, 1920, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (1080, 1920)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[713, 182, 677, 677]], dtype=int32)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %% [markdown]
# <h3 style='color:purple'>(2) Preprocessing: Crop the facial region of the image</h3>

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (677, 677, 3)

# %% [markdown]
# <h3 style='color:purple'>(3) Preprocessing: Use wavelet transform as a feature for traning our model</h3>

# %% [markdown]
# #### In wavelet transformed image, you can see edges clearly and that can give us clues on various facial features such as eyes, nose, lips etc

# %% [markdown]
# ### Wavelet transform

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %% [markdown]
# #### You can see above a wavelet transformed image that gives clues on facial features such as eyes, nose, lips etc. This along with raw pixel image can be used as an input for our classifier

# %% [markdown]
# <h3 style='color:purple'>(3) Preprocessing: Load image, detect face. If eyes >=2, then save and crop the face region</h3>

# %% [markdown]
# ####  Lets write a python function that can take input image and returns cropped images (if face and eyes >=2 are detected)

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    roi = []
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            roi.append(roi_color)
    return roi

# %%
original_image = cv2.imread('./My Images/maria_sharapova/monochrome-maria-sharapova-face-wallpaper-65016-67225-hd-wallpapers.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./My Images/maria_sharapova/monochrome-maria-sharapova-face-wallpaper-65016-67225-hd-wallpapers.jpg')
plt.imshow(cropped_image[0])

# %% [markdown]
# **In below image face is not very clear and it doesn't have two eyes clearly visible**

# %%
org_image_obstructed = cv2.imread('./test_images/sharapova2.jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test_images/sharapova2.jpg')
cropped_image_no_2_eyes
# Out:
# []

# %% [markdown]
# **Above cropped_image_no_2_eyes is None which means we should ignore this image and we will not use such image for model training**

# %% [markdown]
# ### From here we will be getting into training our model. We will also use some of the functions defined above.
# ####  w2d & get_cropped_image_if_2_eyes

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

# %%
path_to_data = "./My Images/"
path_to_cr_data = "./cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./My Images/lionel_messi',
#  './My Images/maria_sharapova',
#  './My Images/roger_federer',
#  './My Images/serena_williams',
#  './My Images/virat_kohli']

# %% [markdown]
# **Go through all images in dataset folder and create cropped images for them. There will be cropped folder inside dataset folder after you run this code**

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi = get_cropped_image_if_2_eyes(entry.path)
        if roi is not None:
            for roi_color in roi:
                cropped_folder = path_to_cr_data + celebrity_name
                if not os.path.exists(cropped_folder):
                    os.makedirs(cropped_folder)
                    cropped_image_dirs.append(cropped_folder)
                    print("Generating cropped images in folder: ",cropped_folder)
                cropped_file_name = celebrity_name + str(count) + ".png"
                cropped_file_path = cropped_folder + "/" + cropped_file_name
                cv2.imwrite(cropped_file_path, roi_color)
                celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
                count += 1
    print('completed')

### Now you should have cropped folder under datasets folder that contains cropped images
# Out:
# Generating cropped images in folder:  ./cropped/lionel_messi
# completed
# Generating cropped images in folder:  ./cropped/maria_sharapova
# completed
# Generating cropped images in folder:  ./cropped/roger_federer
# completed
# Generating cropped images in folder:  ./cropped/serena_williams
# completed
# Generating cropped images in folder:  ./cropped/virat_kohli
# completed

# %% [markdown]
# ### Manually examine cropped folder and delete any unwanted images
# #### We need to get the path of all cropped images

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'lionel_messi': ['./cropped/lionel_messi\\lionel_messi1.png',
#   './cropped/lionel_messi\\lionel_messi10.png',
#   './cropped/lionel_messi\\lionel_messi11.png',
#   './cropped/lionel_messi\\lionel_messi12.png',
#   './cropped/lionel_messi\\lionel_messi15.png',
#   './cropped/lionel_messi\\lionel_messi16.png',
#   './cropped/lionel_messi\\lionel_messi17.png',
#   './cropped/lionel_messi\\lionel_messi18.png',
#   './cropped/lionel_messi\\lionel_messi19.png',
#   './cropped/lionel_messi\\lionel_messi2.png',
#   './cropped/lionel_messi\\lionel_messi20.png',
#   './cropped/lionel_messi\\lionel_messi21.png',
#   './cropped/lionel_messi\\lionel_messi22.png',
#   './cropped/lionel_messi\\lionel_messi23.png',
#   './cropped/lionel_messi\\lionel_messi25.png',
#   './cropped/lionel_messi\\lionel_messi26.png',
#   './cropped/lionel_messi\\lionel_messi27.png',
#   './cropped/lionel_messi\\lionel_messi28.png',
#   './cropped/lionel_messi\\lionel_messi29.png',
#   './cropped/lionel_messi\\lionel_messi3.png',
#   './cropped/lionel_messi\\lionel_messi30.png',
#   './cropped/lionel_messi\\lionel_messi31.png',
#   './cropped/lionel_messi\\lionel_messi32.png',
#   './cropped/lionel_messi\\lionel_messi33.png',
#   './cropped/lionel_messi\\lionel_messi34.png',
#   './cropped/lionel_messi\\lionel_messi38.png',
#   './cropped/lionel_messi\\lionel_messi39.png',
#   './cropped/lionel_messi\\lionel_messi4.png',
#   './cropped/lionel_messi\\lionel_messi40.png',
#   './cropped/lionel_messi\\lionel_messi41.png',
#   './cropped/lionel_messi\\lionel_messi42.png',
#   './cropped/lionel_messi\\lionel_messi43.png',
#   './cropped/lionel_messi\\lionel_messi44.png',
#   './cropped/lionel_messi\\lionel_messi45.png',
#   './cropped/lionel_messi\\lionel_messi46.png',
#   './cropped/lionel_messi\\lionel_messi6.png',
#   './cropped/lionel_messi\\lionel_messi7.png',
#   './cropped/lionel_messi\\lionel_messi8.png',
#   './cropped/lionel_messi\\lionel_messi9.png'],
#  'maria_sharapova': ['./cropped/maria_sharapova\\maria_sharapova10.png',
#   './cropped/maria_sharapova\\maria_sharapova11.png',
#   './cropped/maria_sharapova\\maria_sharapova13.png',
#   './cropped/maria_sharapova\\maria_sharapova14.png',
#   './cropped/maria_sharapova\\maria_sharapova19.png',
#   './cropped/maria_sharapova\\maria_sharapova2.png',
#   './cropped/maria_sharapova\\maria_sharapova21.png',
#   './cropped/maria_sharapova\\maria_sharapova22.png',
#   './cropped/maria_sharapova\\maria_sharapova23.png',
#   './cropped/maria_sharapova\\maria_sharapova24.png',
#   './cropped/maria_sharapova\\maria_sharapova26.png',
#   './cropped/maria_sharapova\\maria_sharapova27.png',
#   './cropped/maria_sharapova\\maria_sharapova28.png',
#   './cropped/maria_sharapova\\maria_sharapova29.png',
#   './cropped/maria_sharapova\\maria_sharapova3.png',
#   './cropped/maria_sharapova\\maria_sharapova30.png',
#   './cropped/maria_sharapova\\maria_sharapova31.png',
#   './cropped/maria_sharapova\\maria_sharapova32.png',
#   './cropped/maria_sharapova\\maria_sharapova33.png',
#   './cropped/maria_sharapova\\maria_sharapova34.png',
#   './cropped/maria_sharapova\\maria_sharapova35.png',
#   './cropped/maria_sharapova\\maria_sharapova36.png',
#   './cropped/maria_sharapova\\maria_sharapova37.png',
#   './cropped/maria_sharapova\\maria_sharapova38.png',
#   './cropped/maria_sharapova\\maria_sharapova39.png',
#   './cropped/maria_sharapova\\maria_sharapova40.png',
#   './cropped/maria_sharapova\\maria_sharapova41.png',
#   './cropped/maria_sharapova\\maria_sharapova42.png',
#   './cropped/maria_sharapova\\maria_sharapova43.png',
#   './cropped/maria_sharapova\\maria_sharapova8.png',
#   './cropped/maria_sharapova\\maria_sharapova9.png'],
#  'roger_federer': ['./cropped/roger_federer\\roger_federer1.png',
#   './cropped/roger_federer\\roger_federer10.png',
#   './cropped/roger_federer\\roger_federer11.png',
#   './cropped/roger_federer\\roger_federer12.png',
#   './cropped/roger_federer\\roger_federer13.png',
#   './cropped/roger_federer\\roger_federer14.png',
#   './cropped/roger_federer\\roger_federer15.png',
#   './cropped/roger_federer\\roger_federer16.png',
#   './cropped/roger_federer\\roger_federer17.png',
#   './cropped/roger_federer\\roger_federer18.png',
#   './cropped/roger_federer\\roger_federer19.png',
#   './cropped/roger_federer\\roger_federer2.png',
#   './cropped/roger_federer\\roger_federer20.png',
#   './cropped/roger_federer\\roger_federer21.png',
#   './cropped/roger_federer\\roger_federer23.png',
#   './cropped/roger_federer\\roger_federer24.png',
#   './cropped/roger_federer\\roger_federer25.png',
#   './cropped/roger_federer\\roger_federer26.png',
#   './cropped/roger_federer\\roger_federer27.png',
#   './cropped/roger_federer\\roger_federer28.png',
#   './cropped/roger_federer\\roger_federer3.png',
#   './cropped/roger_federer\\roger_federer32.png',
#   './cropped/roger_federer\\roger_federer34.png',
#   './cropped/roger_federer\\roger_federer35.png',
#   './cropped/roger_federer\\roger_federer36.png',
#   './cropped/roger_federer\\roger_federer4.png',
#   './cropped/roger_federer\\roger_federer5.png',
#   './cropped/roger_federer\\roger_federer6.png',
#   './cropped/roger_federer\\roger_federer7.png',
#   './cropped/roger_federer\\roger_federer9.png'],
#  'serena_williams': ['./cropped/serena_williams\\serena_williams10.png',
#   './cropped/serena_williams\\serena_williams11.png',
#   './cropped/serena_williams\\serena_williams12.png',
#   './cropped/serena_williams\\serena_williams13.png',
#   './cropped/serena_williams\\serena_williams16.png',
#   './cropped/serena_williams\\serena_williams17.png',
#   './cropped/serena_williams\\serena_williams18.png',
#   './cropped/serena_williams\\serena_williams20.png',
#   './cropped/serena_williams\\serena_williams21.png',
#   './cropped/serena_williams\\serena_williams22.png',
#   './cropped/serena_williams\\serena_williams24.png',
#   './cropped/serena_williams\\serena_williams26.png',
#   './cropped/serena_williams\\serena_williams28.png',
#   './cropped/serena_williams\\serena_williams29.png',
#   './cropped/serena_williams\\serena_williams30.png',
#   './cropped/serena_williams\\serena_williams32.png',
#   './cropped/serena_williams\\serena_williams34.png',
#   './cropped/serena_williams\\serena_williams35.png',
#   './cropped/serena_williams\\serena_williams36.png',
#   './cropped/serena_williams\\serena_williams37.png',
#   './cropped/serena_williams\\serena_williams38.png',
#   './cropped/serena_williams\\serena_williams39.png',
#   './cropped/serena_williams\\serena_williams4.png',
#   './cropped/serena_williams\\serena_williams40.png',
#   './cropped/serena_williams\\serena_williams43.png',
#   './cropped/serena_williams\\serena_williams5.png',
#   './cropped/serena_williams\\serena_williams6.png',
#   './cropped/serena_williams\\serena_williams7.png',
#   './cropped/serena_williams\\serena_williams8.png',
#   './cropped/serena_williams\\serena_williams9.png'],
#  'virat_kohli': ['./cropped/virat_kohli\\virat_kohli1.png',
#   './cropped/virat_kohli\\virat_kohli10.png',
#   './cropped/virat_kohli\\virat_kohli11.png',
#   './cropped/virat_kohli\\virat_kohli13.png',
#   './cropped/virat_kohli\\virat_kohli15.png',
#   './cropped/virat_kohli\\virat_kohli16.png',
#   './cropped/virat_kohli\\virat_kohli17.png',
#   './cropped/virat_kohli\\virat_kohli18.png',
#   './cropped/virat_kohli\\virat_kohli19.png',
#   './cropped/virat_kohli\\virat_kohli2.png',
#   './cropped/virat_kohli\\virat_kohli20.png',
#   './cropped/virat_kohli\\virat_kohli21.png',
#   './cropped/virat_kohli\\virat_kohli22.png',
#   './cropped/virat_kohli\\virat_kohli23.png',
#   './cropped/virat_kohli\\virat_kohli24.png',
#   './cropped/virat_kohli\\virat_kohli26.png',
#   './cropped/virat_kohli\\virat_kohli28.png',
#   './cropped/virat_kohli\\virat_kohli29.png',
#   './cropped/virat_kohli\\virat_kohli30.png',
#   './cropped/virat_kohli\\virat_kohli31.png',
#   './cropped/virat_kohli\\virat_kohli33.png',
#   './cropped/virat_kohli\\virat_kohli34.png',
#   './cropped/virat_kohli\\virat_kohli35.png',
#   './cropped/virat_kohli\\virat_kohli36.png',
#   './cropped/virat_kohli\\virat_kohli38.png',
#   './cropped/virat_kohli\\virat_kohli39.png',
#   './cropped/virat_kohli\\virat_kohli4.png',
#   './cropped/virat_kohli\\virat_kohli40.png',
#   './cropped/virat_kohli\\virat_kohli42.png',
#   './cropped/virat_kohli\\virat_kohli43.png',
#   './cropped/virat_kohli\\virat_kohli45.png',
#   './cropped/virat_kohli\\virat_kohli46.png',
#   './cropped/virat_kohli\\virat_kohli47.png',
#   './cropped/virat_kohli\\virat_kohli48.png',
#   './cropped/virat_kohli\\virat_kohli50.png',
#   './cropped/virat_kohli\\virat_kohli51.png',
#   './cropped/virat_kohli\\virat_kohli52.png',
#   './cropped/virat_kohli\\virat_kohli53.png',
#   './cropped/virat_kohli\\virat_kohli54.png',
#   './cropped/virat_kohli\\virat_kohli55.png',
#   './cropped/virat_kohli\\virat_kohli6.png',
#   './cropped/virat_kohli\\virat_kohli7.png',
#   './cropped/virat_kohli\\virat_kohli8.png',
#   './cropped/virat_kohli\\virat_kohli9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'lionel_messi': 0,
#  'maria_sharapova': 1,
#  'roger_federer': 2,
#  'serena_williams': 3,
#  'virat_kohli': 4}

# %% [markdown]
# ### Images in cropped folder can be used for model training. We will use these raw images along with wavelet transformed images to train our classifier. Let's prepare X and y now

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (174, 4096)

# %% [markdown]
# ### Data cleaning process is done. Now we are ready to train our model

# %% [markdown]
# We will use SVM with rbf kernel tuned  with heuristic finetuning

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.8863636363636364

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.70      0.78        10
#            1       0.90      0.90      0.90        10
#            2       0.86      1.00      0.92         6
#            3       0.88      0.88      0.88         8
#            4       0.91      1.00      0.95        10
#
#     accuracy                           0.89        44
#    macro avg       0.88      0.89      0.89        44
# weighted avg       0.89      0.89      0.88        44

# %% [markdown]
# ### Let's use GridSearch to try out different models with different paramets. Goal is to come up with best modle with best fine tuned parameters

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.838462
# 1        random_forest    0.700000
# 2  logistic_regression    0.838462
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.9090909090909091

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.75

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.9090909090909091

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 8,  1,  1,  0,  0],
#        [ 1,  9,  0,  0,  0],
#        [ 0,  0,  6,  0,  0],
#        [ 0,  0,  1,  7,  0],
#        [ 0,  0,  0,  0, 10]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'lionel_messi': 0,
#  'maria_sharapova': 1,
#  'roger_federer': 2,
#  'serena_williams': 3,
#  'virat_kohli': 4}

# %% [markdown]
# ### Save the trained model

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in d:\programdata\anaconda3\envs\conda_env\lib\site-packages (1.0.1)
# ['saved_model.pkl']

# %% [markdown]
# ### Save class dictionary

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
